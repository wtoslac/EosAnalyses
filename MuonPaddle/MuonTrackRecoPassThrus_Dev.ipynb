# %% [markdown]
# For this project, I am using run7722all_metafix.root that was produced by Arran using his custom Data processor that includes the muon hits (muon_paddle_hits) and the positions of each paddle in the meta tree.<br>
#
# The data contains the data processed for the water PMTs also to link the muon hits with the PMT pulses.<br>

# %%
# This block install some 3D plotting capability to your python install. 
# Uncomment and run once to install ipymp or plotly
#%pip install ipympl
#%pip install plotly

# %%
# Let's print out the output tree.
import ROOT
f = ROOT.TFile.Open("../Data/run7722all_metafix.root")
output = f.Get("output")
output.Print()

# %% [markdown]
# The print out shows that the output tree has 353719 events. The useful variables for this analysis are
# - muon_paddle_hits: 1s and 0s whether or not the paddle is hit out of the 134 total.
# - digitNHits or digitNhitsCleaned: This is tell us how much energy is deposited in the water tank.
# - digitCharge: Same as above but more direct correlation to energy.

# %%
# This block just check if the digitNhits are valid for this dataset.
import ROOT
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
# Create RDataFrame from the events tree of the input file.
rdf = ROOT.RDataFrame("output", "../Data/run7722all_metafix.root")
# Extract nhits values
digitNhits = rdf.AsNumpy(columns=["digitNhits"])["digitNhits"]
# Histogramming
digitNhits_counts, digitNhits_bins = np.histogram(digitNhits, bins=np.arange(0, 240, 1))
digitNhits_bin_centers = [(digitNhits_bins[i] + digitNhits_bins[i + 1]) / 2 for i in range(len(digitNhits_bins) - 1)]
# Plotting
plt.figure(figsize=(12, 6))
plt.title(f"nhits histogram")
plt.errorbar(digitNhits_bin_centers, digitNhits_counts,
             ls='', marker='o', mfc='black', ms=4, mec='black',
             ecolor='black', label="Run 7722")

plt.xlabel("digitNhits", fontsize=18)
plt.ylabel("NEvents", fontsize=15)
plt.yscale('log')
#plt.ylim(3000,250_000)
plt.legend()
plt.show()

# %% [markdown]
# This digitNhtis looks pretty normal for Muon Data. There's probably a lot of different events and noise mix into it but hopefully the Muon paddle data will help with this.

# %%
# This prints out the meta tree.
import ROOT
f = ROOT.TFile.Open("../Data/run7722all_metafix.root")
meta = f.Get("meta")
meta.Print()

# %% [markdown]
# We need the values from muon_paddle_x,y,z.

# %%
import ROOT
import numpy as np
import matplotlib.pyplot as plt

meta = ROOT.RDataFrame("meta", "../Data/run7722all_metafix.root")

#muon_paddle_x = meta.AsNumpy(columns=["muon_paddle_x"])
#print(muon_paddle_x)

#muon_paddle_y = meta.AsNumpy(columns=["muon_paddle_y"])
#print(muon_paddle_y)

muon_paddle_z = meta.AsNumpy(columns=["muon_paddle_z"])["muon_paddle_z"][0]
print(muon_paddle_z.shape)
#print(muon_paddle_z[0].shape)

# %% [markdown]
# muon_paddle_x,y,z seems to be 164x134 shape. The 134 is for the number of paddles, 164 is actually from the number of root/hdf5 files that were combined together.

# %% [markdown]
# What I want to do is to combine the position in the meta and hits from output together into a single array for analysis.
#
# ## Run this box to produce muon_pos_hits array

# %%
# Code to combine layer#, xyz positions of the paddle and the event by event hits.
# Layer is the row 0, xyz are row 1 to 3, hit data are 4 to NEvents+4
import ROOT
import numpy as np
import matplotlib.pyplot as plt

meta = ROOT.RDataFrame("meta", "../Data/run7722all_metafix.root")
# Get the xyz position, but we just need the 1st entry (hdf5 file).
x_pos = meta.AsNumpy(columns=["muon_paddle_x"])["muon_paddle_x"][0]
y_pos = meta.AsNumpy(columns=["muon_paddle_y"])["muon_paddle_y"][0]
z_pos = meta.AsNumpy(columns=["muon_paddle_z"])["muon_paddle_z"][0]
#print("x_pos shape:", x_pos.shape)
#print("y_pos shape:", y_pos.shape)
#print("z_pos shape:", z_pos.shape)

output = ROOT.RDataFrame("output", "../Data/run7722all_metafix.root")
# Convert from object array of event vectors to 2D array: NEvents x 134
muon_hits = np.stack(
    output.AsNumpy(["muon_paddle_hit"])["muon_paddle_hit"]
)

# Paddle indices to disable
disabled_paddles = np.array([0, 1, 7, 10, 11, 13, 14, 23, 29, 40, 41, 44, 45, 46,
    48, 49, 51, 58, 65, 67, 75, 78, 81, 82, 88, 93, 103,
    106, 107, 108, 110, 112, 114, 128, 130, 132, 133], dtype=int)

# Validate the indices before applying the mask
disabled_paddles = disabled_paddles[
    (disabled_paddles >= 0) &
    (disabled_paddles < muon_hits.shape[1])
]

# Set these paddles to zero for every event
muon_hits[:, disabled_paddles] = 0



print("muon_hits shape:", muon_hits.shape)

# Put a value for the layers 
layer = np.zeros_like(z_pos, dtype=int) # defaults to 0
layer[np.isclose(z_pos, 2129.984)] = 1 # TopUpper-x
layer[np.isclose(z_pos, 2098.311)] = 2 # TopUpper+x
layer[np.isclose(z_pos, 1972.377)] = 3 # TopLower-y
layer[np.isclose(z_pos, 1940.704)] = 4 # TopLower+y
layer[np.isclose(z_pos, 699.896)] = 5 # Barrel+z
layer[np.isclose(z_pos, -398.908)] = 6 # Barrel-z
layer[np.isclose(z_pos, -1807.338)] = 7 # Bottom-y
layer[np.isclose(z_pos, -1839.012)] = 8 # Bottom+y

# Stack x, y, z as first 3 rows
muon_pos_hits = np.vstack([
    layer,
    x_pos,
    y_pos,
    z_pos,
    muon_hits
])

print("muon_hits_with_pos shape:", muon_pos_hits[0])
# Out:
# muon_hits shape: (353719, 134)
# muon_hits_with_pos shape: [6. 5. 6. 3. 6. 5. 3. 4. 6. 5. 0. 0. 8. 2. 2. 3. 0. 8. 8. 8. 8. 8. 6. 6.
#  6. 6. 6. 8. 8. 8. 8. 8. 6. 6. 6. 6. 6. 6. 6. 6. 4. 5. 4. 4. 3. 4. 3. 7.
#  1. 1. 4. 4. 7. 7. 7. 7. 7. 5. 5. 5. 5. 5. 7. 7. 7. 7. 7. 5. 5. 5. 5. 5.
#  5. 5. 5. 6. 0. 3. 0. 3. 4. 0. 6. 6. 5. 5. 6. 6. 5. 5. 6. 6. 5. 5. 6. 6.
#  5. 5. 6. 6. 5. 5. 6. 6. 5. 5. 0. 0. 2. 6. 1. 5. 2. 6. 1. 5. 2. 2. 1. 1.
#  2. 2. 1. 1. 2. 2. 1. 1. 3. 6. 4. 5. 0. 0.]

# %%
# Just checking the xyz for particular z position paddles
print(muon_pos_hits[1:4,np.where(np.isclose(muon_pos_hits[3,], -1839.012))[0]])

# %% [markdown]
# ## Let's look for the easiest events first.
# The muon passes through TopUpper, TopLower and Bottom. Assuming the muon is travel almost straight, the three paddle should have a path that can be intersected by a straight line.<br>
#
# Let's filter for the events that has 1 hit on each TopUpper, TopLower and Bottom and no hits on the barrel.

# %%
# Get columns from layer info
TopUpper = np.where((muon_pos_hits[0] == 1) | (muon_pos_hits[0] == 2))[0]
TopLower = np.where((muon_pos_hits[0] == 3) | (muon_pos_hits[0] == 4))[0]
Bottom = np.where((muon_pos_hits[0] == 7) | (muon_pos_hits[0] == 8))[0]
Barrel = np.where((muon_pos_hits[0] == 5) | (muon_pos_hits[0] == 6))[0]

#print("TopUpper columns:", TopUpper)
#print("TopLower columns:", TopLower)

# Count hits only in the selected layer groups
top_upper_hits = np.count_nonzero(muon_pos_hits[4:, TopUpper] == 1, axis=1)
top_lower_hits = np.count_nonzero(muon_pos_hits[4:, TopLower] == 1, axis=1)
bottom_hits = np.count_nonzero(muon_pos_hits[4:, Bottom] == 1, axis=1)
barrel_hits = np.count_nonzero(muon_pos_hits[4:, Barrel] == 1, axis=1)
event_list = []

for event_number, upper_count, lower_count, bottom_count, barrel_count in zip(
    range(len(muon_pos_hits[4:])),
    top_upper_hits,
    top_lower_hits,
    bottom_hits,
    barrel_hits
):
    if upper_count == 1 and lower_count == 1 and bottom_count == 1 and barrel_count == 0:
        event_list.append(event_number)
        print(
            f"Event {event_number}: "
            f"TopUpper = {upper_count} hits, "
            f"TopLower = {lower_count} hits"
            f"Bottom = {bottom_count} hits"
            f"Barrel = {barrel_count} hits"
        
        )
print("len(event_list), ",len(event_list))
# Out:
# Event 863: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 1378: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 1775: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 4870: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 5107: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 7374: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 7512: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 11466: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 15229: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 20018: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 21605: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 22253: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 22278: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 26588: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 26866: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 27853: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 28914: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 29363: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 30450: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 30636: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 32201: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 35042: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 35987: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 37000: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 39438: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 39625: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 48181: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 54816: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 56850: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 62910: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 67138: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 69014: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 70181: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 71237: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 77134: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 78407: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 79078: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 81288: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 82612: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 86844: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 89714: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 93596: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 94425: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 94822: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 97451: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 103467: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 105951: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 106298: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 107793: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 109172: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 111544: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 111839: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 113225: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 113921: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 119124: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 122108: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 124284: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 125013: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 126402: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 128978: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 133336: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 137401: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 140191: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 141168: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 143816: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 146709: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 152551: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 152688: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 153351: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 155137: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 156767: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 157238: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 157421: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 157963: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 158384: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 158386: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 159236: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 162750: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 166326: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 166856: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 169502: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 170084: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 171264: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 173661: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 177337: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 181006: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 182714: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 184013: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 188650: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 189078: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 191106: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 192087: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 192148: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 192631: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 192868: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 193227: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 201373: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 202599: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 207399: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 207606: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 209633: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 215973: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 217005: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 217311: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 218766: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 220199: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 221098: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 222448: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 227473: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 231012: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 232751: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 234268: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 235164: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 237496: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 237987: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 238370: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 241494: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 249953: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 251364: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 252825: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 254242: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 255572: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 255632: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 256524: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 258016: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 258834: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 259300: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 259453: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 259617: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 261644: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 262273: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 263232: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 263311: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 264066: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 264963: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 265852: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 267203: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 268191: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 269178: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 269793: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 274778: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 276208: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 276258: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 276650: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 277627: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 277905: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 280434: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 281042: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 292063: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 295240: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 298365: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 300532: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 302482: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 307515: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 312269: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 312499: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 314414: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 314693: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 314947: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 316305: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 319273: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 327756: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 328328: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 328441: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 331154: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 334365: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 334703: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 339427: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 340756: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 349917: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 351601: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# Event 351972: TopUpper = 1 hits, TopLower = 1 hitsBottom = 1 hitsBarrel = 0 hits
# len(event_list),  172

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from MuonTrack import *
# Use Qt backend for smoother 3D rotation
# Run this once in a separate notebook cell if needed:
# %matplotlib qt

EVENTNUM = 349917


event_hit_row = 4 + EVENTNUM

hit_columns = np.where(muon_pos_hits[event_hit_row] == 1)[0]

print(f"Event {EVENTNUM}")
print("hit columns:", hit_columns)
print("number of hits:", len(hit_columns))

fig = plt.figure(figsize=(10, 11))
ax = fig.add_subplot(111, projection="3d")

for col in hit_columns:
    layer_value = int(muon_pos_hits[0, col])

    x = muon_pos_hits[1, col]
    y = muon_pos_hits[2, col]
    z = muon_pos_hits[3, col]

    print(f"  col {col}: layer={layer_value}, x={x}, y={y}, z={z}")

    if layer_value == 1:
        draw_paddle(ax, center=(x, y, z), size=(1300, 210, 10), alpha=0.35,facecolor=color_from_layer(layer_value))
    elif layer_value == 2:
        draw_paddle(ax, center=(x, y, z), size=(1300, 210, 10), alpha=0.35,facecolor=color_from_layer(layer_value))
    elif layer_value == 3:
        draw_paddle(ax, center=(x, y, z), size=(210, 1300, 10), alpha=0.35,facecolor=color_from_layer(layer_value))    
    elif layer_value == 4:
        draw_paddle(ax, center=(x, y, z), size=(210, 1300, 10), alpha=0.35,facecolor=color_from_layer(layer_value))
    elif layer_value == 5:
        draw_paddle(ax, center=(x, y, z), size=(210, 210, 1300), alpha=0.35,facecolor=color_from_layer(layer_value))
    elif layer_value == 6:
        draw_paddle(ax, center=(x, y, z), size=(210, 210, 1300), alpha=0.35,facecolor=color_from_layer(layer_value))
    elif layer_value == 7:
        draw_paddle(ax, center=(x, y, z), size=(210, 1300, 10), alpha=0.35,facecolor=color_from_layer(layer_value))    
    elif layer_value == 8:
        draw_paddle(ax, center=(x, y, z), size=(210, 1300, 10), alpha=0.35,facecolor=color_from_layer(layer_value))
    else:
        ax.scatter(x, y, z, s=80)

    ax.text(x, y, z, layer_value, fontsize=9)


ax.set_xlabel("x_pos")
ax.set_ylabel("y_pos")
ax.set_zlabel("z_pos")
ax.set_title(f"Event {EVENTNUM}: Muon Hits with Layer #")

ax.set_xlim(-1600, 1600)
ax.set_ylim(-1600, 1600)
ax.set_zlim(-2200, 2200)

ax.set_box_aspect((3200, 3200, 4400))

plt.show()

# %% [markdown]
# ## Now let's try to fit tracks through these boxes if possible.
# The best track should be those going through the center of each box.

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from MuonTrack import *
# Use Qt backend for smoother 3D rotation
# Run this once in a separate notebook cell if needed:
# %matplotlib qt

EVENTNUM = 1775

event_hit_row = 4 + EVENTNUM

hit_columns = np.where(muon_pos_hits[event_hit_row] == 1)[0]

print(f"Event {EVENTNUM}")
print("hit columns:", hit_columns)
print("number of hits:", len(hit_columns))

fig = plt.figure(figsize=(10, 11))
ax = fig.add_subplot(111, projection="3d")
hit_boxes = []
hit_centers = []
hit_layers = []
hit_cols = []


for col in hit_columns:
    layer_value = int(muon_pos_hits[0, col])

    x = muon_pos_hits[1, col]
    y = muon_pos_hits[2, col]
    z = muon_pos_hits[3, col]

    print(f"  col {col}: layer={layer_value}, x={x}, y={y}, z={z}")
    
    size = box_size_from_layer(layer_value)
    
    if size is not None:
        draw_paddle(ax, center=(x, y, z), size=size, alpha=0.35, facecolor=color_from_layer(layer_value))

    ax.text(x, y, z, str(layer_value), fontsize=9)

    if size is not None:
        hit_boxes.append({
            "center": np.array([x, y, z], dtype=float),
            "size": np.array(size, dtype=float),
            "bounds": box_bounds(center=(x, y, z), size=size),
            "col": col,
            "layer": layer_value,
        })
    
    hit_centers.append([x, y, z])
    hit_layers.append(layer_value)
    hit_cols.append(col)


ax.set_xlabel("x_pos")
ax.set_ylabel("y_pos")
ax.set_zlabel("z_pos")
ax.set_title(f"Event {EVENTNUM}: Muon Hits with Layer #")

ax.set_xlim(-1600, 1600)
ax.set_ylim(-1600, 1600)
ax.set_zlim(-2200, 2200)

ax.set_box_aspect((3200, 3200, 4400))
hit_centers = np.array(hit_centers, dtype=float)

if len(hit_boxes) >= 2:
    line_point, line_dir, score = fit_line_through_boxes(
        hit_boxes,
        n_trials=10000,
        seed=12345
    )

    if line_point is None:
        print("No line found that intersects all hit boxes.")
        print("Try increasing n_trials.")
    else:
        # Project box centers onto fitted line to choose display length
        centers = np.array([b["center"] for b in hit_boxes], dtype=float)
        t_values = (centers - line_point) @ line_dir

        t_min = t_values.min() - 700
        t_max = t_values.max() + 700

        t_line = np.linspace(t_min, t_max, 100)
        line_xyz = line_point + np.outer(t_line, line_dir)

        ax.plot(
            line_xyz[:, 0],
            line_xyz[:, 1],
            line_xyz[:, 2],
            color="red",
            linewidth=3,
            label="box-aware central line"
        )

        print("\nBox-aware fitted line:")
        print("  point     =", line_point)
        print("  direction =", line_dir)
        print("  score     =", score)

        print("\nDistances from hit box centers to fitted line:")
        for box in hit_boxes:
            dist = point_line_distance(box["center"], line_point, line_dir)
            print(
                f"  col {box['col']}, layer {box['layer']}: "
                f"distance = {dist:.3f}"
            )

        ax.legend()
        ax.text(
            0.5, 0.5,
            "Work In Progress",
            transform=ax.transAxes,
            fontsize=45,
            color="gray",
            alpha=0.25,
            ha="center",
            va="center",
            rotation=-30,
            zorder=1000
        )
else:
    print("Need at least 2 hit boxes to fit a line.")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      11 EVENTNUM = 1775
#      12
#      13 event_hit_row = 4 + EVENTNUM
#      14
# ---> 15 hit_columns = np.where(muon_pos_hits[event_hit_row] == 1)[0]
#      16
#      17 print(f"Event {EVENTNUM}")
#      18 print("hit columns:", hit_columns)
#
# NameError: name 'muon_pos_hits' is not defined

# %%
# Get columns from layer info
TopUpper = np.where((muon_pos_hits[0] == 1) | (muon_pos_hits[0] == 2))[0]
TopLower = np.where((muon_pos_hits[0] == 3) | (muon_pos_hits[0] == 4))[0]
Bottom = np.where((muon_pos_hits[0] == 7) | (muon_pos_hits[0] == 8))[0]
Barrel = np.where((muon_pos_hits[0] == 5) | (muon_pos_hits[0] == 6))[0]

#print("TopUpper columns:", TopUpper)
#print("TopLower columns:", TopLower)

# Count hits only in the selected layer groups
top_upper_hits = np.count_nonzero(muon_pos_hits[4:, TopUpper] == 1, axis=1)
top_lower_hits = np.count_nonzero(muon_pos_hits[4:, TopLower] == 1, axis=1)
bottom_hits = np.count_nonzero(muon_pos_hits[4:, Bottom] == 1, axis=1)
barrel_hits = np.count_nonzero(muon_pos_hits[4:, Barrel] == 1, axis=1)
event_list = []

for event_number, upper_count, lower_count, bottom_count, barrel_count in zip(
    range(len(muon_pos_hits[4:])),
    top_upper_hits,
    top_lower_hits,
    bottom_hits,
    barrel_hits
):
    if upper_count == 1 and lower_count == 1 and bottom_count == 1 and barrel_count == 0:
        event_list.append(event_number)
       # print(
       #     f"Event {event_number}: "
       #     f"TopUpper = {upper_count} hits, "
       #     f"TopLower = {lower_count} hits"
       #     f"Bottom = {bottom_count} hits"
       #     f"Barrel = {barrel_count} hits"
       #     )

fit_results = []

for EVENTNUM in event_list:
    result = test_event_fit(
        EVENTNUM,
        muon_pos_hits,
        n_trials=10000,
        seed=12345
    )

    fit_results.append(result)

    status = "SUCCESS" if result["success"] else "FAIL"

    print(
        f"Event {EVENTNUM}: {status}, "
        f"n_hits={result['n_hits']}, "
        f"score={result['score']}, "
        f"reason={result['reason']}"
    )

    print(f"  hit columns: {result['hit_columns']}")

    if result["success"]:
        print(f"  line point: {result['line_point']}")
        print(f"  line dir  : {result['line_dir']}")

    print()

n_success = sum(1 for r in fit_results if r["success"])
n_fail = sum(1 for r in fit_results if not r["success"])

print(f"Total success: {n_success}")
print(f"Total fail:    {n_fail}")
print(f"Total events:  {len(fit_results)}")
# Out:
# Event 863: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 66, 118]
#
# Event 1378: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [30, 50, 118]
#
# Event 1775: SUCCESS, n_hits=3, score=0.28421325657637314, reason=fit successful
#   hit columns: [3, 55, 126]
#   line point: [  251.65130224  -662.35341687 -1810.7045031 ]
#   line dir  : [-0.24180203  0.09181161  0.96597226]
#
# Event 4870: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 42, 127]
#
# Event 5107: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 63, 122]
#
# Event 7374: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 43, 76, 127]
#
# Event 7512: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 52, 76, 127]
#
# Event 11466: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 50, 118]
#
# Event 15229: SUCCESS, n_hits=3, score=0.18415480053455086, reason=fit successful
#   hit columns: [3, 12, 118]
#   line point: [ 1257.73305115   592.97840258 -1841.71298114]
#   line dir  : [-0.43653605 -0.27879337  0.8554008 ]
#
# Event 20018: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 66, 122]
#
# Event 21605: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 63, 76, 127]
#
# Event 22253: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 63, 126]
#
# Event 22278: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [27, 50, 122]
#
# Event 26588: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 42, 123]
#
# Event 26866: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 55, 119]
#
# Event 27853: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 55, 122]
#
# Event 28914: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 55, 126]
#
# Event 29363: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 47, 76, 123]
#
# Event 30450: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 42, 123]
#
# Event 30636: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [55, 79, 127]
#
# Event 32201: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [17, 79, 127]
#
# Event 35042: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 80, 124]
#
# Event 35987: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 55, 127]
#
# Event 37000: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 50, 118]
#
# Event 39438: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 50, 126]
#
# Event 39625: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 42, 127]
#
# Event 48181: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 43, 76, 127]
#
# Event 54816: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 52, 119]
#
# Event 56850: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 50, 122]
#
# Event 62910: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [55, 79, 127]
#
# Event 67138: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 50, 122]
#
# Event 69014: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 63, 119]
#
# Event 70181: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 79, 127]
#
# Event 71237: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 80, 116]
#
# Event 77134: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [47, 50, 126]
#
# Event 78407: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [63, 79, 119]
#
# Event 79078: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 64, 118]
#
# Event 81288: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 55, 118]
#
# Event 82612: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [52, 79, 126]
#
# Event 86844: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 50, 126]
#
# Event 89714: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 43, 76, 127]
#
# Event 93596: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 42, 119]
#
# Event 94425: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 53, 123]
#
# Event 94822: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 63, 127]
#
# Event 97451: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 66, 126]
#
# Event 103467: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 50, 126]
#
# Event 105951: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 42, 123]
#
# Event 106298: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [17, 79, 127]
#
# Event 107793: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 52, 126]
#
# Event 109172: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 79, 127]
#
# Event 111544: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [19, 50, 118]
#
# Event 111839: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [18, 50, 122]
#
# Event 113225: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 79, 119]
#
# Event 113921: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [66, 79, 127]
#
# Event 119124: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [64, 79, 127]
#
# Event 122108: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 63, 76, 119]
#
# Event 124284: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 43, 119]
#
# Event 125013: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 43, 76, 127]
#
# Event 126402: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [30, 43, 123]
#
# Event 128978: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [17, 42, 127]
#
# Event 133336: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 43, 119]
#
# Event 137401: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [53, 79, 127]
#
# Event 140191: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [15, 66, 121]
#
# Event 141168: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [18, 79, 119]
#
# Event 143816: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [19, 80, 116]
#
# Event 146709: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 55, 126]
#
# Event 152551: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [30, 43, 127]
#
# Event 152688: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 50, 126]
#
# Event 153351: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 52, 76, 127]
#
# Event 155137: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [12, 42, 127]
#
# Event 156767: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 42, 127]
#
# Event 157238: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [55, 80, 116]
#
# Event 157421: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [12, 43, 76, 123]
#
# Event 157963: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [17, 80, 124]
#
# Event 158384: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 63, 122]
#
# Event 158386: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 55, 122]
#
# Event 159236: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [18, 43, 123]
#
# Event 162750: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [30, 42, 127]
#
# Event 166326: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [55, 79, 127]
#
# Event 166856: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 80, 116]
#
# Event 169502: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [15, 47, 121]
#
# Event 170084: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 43, 76, 127]
#
# Event 171264: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [17, 42, 127]
#
# Event 173661: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 79, 127]
#
# Event 177337: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [66, 80, 119]
#
# Event 181006: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 55, 124]
#
# Event 182714: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [53, 79, 127]
#
# Event 184013: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 52, 76, 127]
#
# Event 188650: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 66, 76, 127]
#
# Event 189078: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [66, 80, 122]
#
# Event 191106: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [31, 79, 123]
#
# Event 192087: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 66, 76, 119]
#
# Event 192148: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [47, 50, 126]
#
# Event 192631: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [63, 79, 127]
#
# Event 192868: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [47, 50, 122]
#
# Event 193227: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 43, 76, 119]
#
# Event 201373: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 52, 122]
#
# Event 202599: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 63, 126]
#
# Event 207399: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 42, 127]
#
# Event 207606: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 55, 127]
#
# Event 209633: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [15, 21, 121]
#
# Event 215973: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 79, 127]
#
# Event 217005: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 79, 119]
#
# Event 217311: SUCCESS, n_hits=3, score=0.14652603982067194, reason=fit successful
#   hit columns: [3, 53, 122]
#   line point: [  749.73305115  -505.82559742 -1810.03898114]
#   line dir  : [-0.35966202  0.00488694  0.93306985]
#
# Event 218766: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 42, 119]
#
# Event 220199: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 79, 127]
#
# Event 221098: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [27, 79, 123]
#
# Event 222448: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [30, 42, 118]
#
# Event 227473: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 42, 127]
#
# Event 231012: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 53, 118]
#
# Event 232751: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 63, 127]
#
# Event 234268: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [17, 50, 122]
#
# Event 235164: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 47, 119]
#
# Event 237496: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [55, 79, 123]
#
# Event 237987: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 50, 126]
#
# Event 238370: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [30, 79, 119]
#
# Event 241494: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [17, 43, 127]
#
# Event 249953: SUCCESS, n_hits=3, score=0.29301012579296776, reason=fit successful
#   hit columns: [6, 27, 118]
#   line point: [-1262.60676534   645.90182068 -1834.96354825]
#   line dir  : [ 0.23950318 -0.31219839  0.91933149]
#
# Event 251364: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [54, 79, 127]
#
# Event 252825: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 50, 118]
#
# Event 254242: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 43, 127]
#
# Event 255572: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 55, 118]
#
# Event 255632: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 66, 76, 127]
#
# Event 256524: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 55, 118]
#
# Event 258016: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 55, 76, 119]
#
# Event 258834: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [18, 79, 119]
#
# Event 259300: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 63, 127]
#
# Event 259453: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [63, 80, 116]
#
# Event 259617: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 42, 119]
#
# Event 261644: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 43, 76, 119]
#
# Event 262273: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 43, 127]
#
# Event 263232: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 50, 118]
#
# Event 263311: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 50, 126]
#
# Event 264066: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 56, 118]
#
# Event 264963: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [63, 79, 119]
#
# Event 265852: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 55, 118]
#
# Event 267203: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 56, 126]
#
# Event 268191: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [31, 43, 119]
#
# Event 269178: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [27, 43, 127]
#
# Event 269793: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 43, 76, 119]
#
# Event 274778: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 66, 122]
#
# Event 276208: SUCCESS, n_hits=3, score=0.10719740091529453, reason=fit successful
#   hit columns: [3, 66, 122]
#   line point: [ -254.17516516  -537.06828526 -1809.87346243]
#   line dir  : [-0.11258762  0.01238296  0.99356464]
#
# Event 276258: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 66, 118]
#
# Event 276650: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [20, 79, 127]
#
# Event 277627: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 50, 118]
#
# Event 277905: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [12, 79, 127]
#
# Event 280434: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [15, 55, 121]
#
# Event 281042: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [52, 79, 123]
#
# Event 292063: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 50, 126]
#
# Event 295240: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [16, 50, 56, 122]
#
# Event 298365: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 43, 119]
#
# Event 300532: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 43, 127]
#
# Event 302482: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [55, 79, 119]
#
# Event 307515: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [17, 79, 119]
#
# Event 312269: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 63, 118]
#
# Event 312499: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [18, 50, 126]
#
# Event 314414: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 50, 118]
#
# Event 314693: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 66, 76, 123]
#
# Event 314947: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [43, 52, 76, 123]
#
# Event 316305: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [28, 80, 116]
#
# Event 319273: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 79, 119]
#
# Event 327756: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [17, 50, 118]
#
# Event 328328: SUCCESS, n_hits=3, score=0.16967256176625675, reason=fit successful
#   hit columns: [6, 18, 118]
#   line point: [  763.49122208   532.31231009 -1842.35317215]
#   line dir  : [-0.25033552 -0.28548933  0.92510971]
#
# Event 328441: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 55, 118]
#
# Event 331154: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [66, 80, 116]
#
# Event 334365: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [63, 79, 127]
#
# Event 334703: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [66, 79, 127]
#
# Event 339427: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [42, 47, 123]
#
# Event 340756: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [50, 56, 118]
#
# Event 349917: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [12, 43, 76, 123]
#
# Event 351601: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [21, 79, 127]
#
# Event 351972: FAIL, n_hits=3, score=None, reason=no line found that intersects all hit boxes
#   hit columns: [47, 79, 119]
#
# Total success: 6
# Total fail:    166
# Total events:  172

# %% [markdown]
# ## Looking at DigiNhits for events that has a straight track fitting or not.

# %%
import ROOT
import numpy as np
import matplotlib.pyplot as plt

rdf = ROOT.RDataFrame("output", "../Data/run7722all_metafix.root")

digitNhits = rdf.AsNumpy(columns=["digitNhits"])["digitNhits"]
n_events = len(digitNhits)

bins = np.arange(0, 240, 5)

success_counts, digitNhits_bins = np.histogram(digitNhits[np.array(
    [r["event"] for r in fit_results if r["success"]],
    dtype=int
)], bins=bins)

fail_counts, _ = np.histogram(digitNhits[np.array([r["event"] for r in fit_results if not r["success"]],dtype=int)], bins=bins)

# Normalize fail histogram to same total as success histogram
if np.sum(fail_counts) > 0:
    fail_counts = fail_counts * np.sum(success_counts) / np.sum(fail_counts)

digitNhits_bin_centers = 0.5 * (digitNhits_bins[:-1] + digitNhits_bins[1:])

plt.figure(figsize=(12, 6))
plt.title("digitNhits histogram: fit success vs fit fail")

plt.plot(
    digitNhits_bin_centers,
    success_counts,
    color="blue",
    label=f"Fit success ({len(event_success)} events)"
)

plt.plot(
    digitNhits_bin_centers,
    fail_counts,
    color="red",
    label=f"Fit fail normalized ({len(event_fail)} events)"
)

plt.xlabel("digitNhits", fontsize=18)
plt.ylabel("NEvents", fontsize=15)
plt.yscale("log")
plt.legend()
plt.show()

# %%
import ROOT
import numpy as np
import matplotlib.pyplot as plt

def plot_digitNhits_event_list(
    event_list,
    root_file="../Data/run7722all_metafix.root",
    tree_name="output",
    bins=np.arange(0, 210, 5),
    normalize_red=True
):
    rdf = ROOT.RDataFrame(tree_name, root_file)

    digitNhits = rdf.AsNumpy(columns=["digitNhits"])["digitNhits"]
    n_events = len(digitNhits)

    event_list = np.array(event_list, dtype=int)

    # Keep only valid event numbers
    event_list = event_list[(event_list >= 0) & (event_list < n_events)]

    # Blue: events in event_list
    selected_events = event_list

    # Red: events not in event_list
    all_events = np.arange(n_events, dtype=int)
    other_events = np.setdiff1d(all_events, selected_events)

    selected_digitNhits = digitNhits[selected_events]
    other_digitNhits = digitNhits[other_events]

    selected_counts, digitNhits_bins = np.histogram(
        selected_digitNhits,
        bins=bins
    )

    other_counts, _ = np.histogram(
        other_digitNhits,
        bins=bins
    )

    # Optional: normalize red histogram to same total as blue histogram
    if normalize_red and np.sum(other_counts) > 0:
        other_counts = other_counts * np.sum(selected_counts) / np.sum(other_counts)

    digitNhits_bin_centers = 0.5 * (
        digitNhits_bins[:-1] + digitNhits_bins[1:]
    )

    plt.figure(figsize=(12, 6))
    plt.title("digitNhits histogram: selected events vs all other events")

    plt.errorbar(
        digitNhits_bin_centers[1:-1],
        selected_counts[1:-1],
        yerr=np.sqrt(selected_counts[1:-1]),
        color="black",
        marker=".",
        linestyle="",
        capsize=2,
        label=f"Triple Hits ({len(selected_events)} events)"
    )

    plt.bar(
        digitNhits_bin_centers[1:-1],
        other_counts[1:-1],
        width=5,
        color="blue",
        alpha=0.5,
        label=f"Not Triple Hits ({len(other_events)} events)"
    )

    plt.xlabel("digitNhits", fontsize=18)
    plt.ylabel("NEvents", fontsize=15)
    #plt.yscale("log")
    plt.legend()
    plt.show()

    return selected_events, other_events, selected_counts, other_counts

selected_events, other_events, selected_counts, other_counts = plot_digitNhits_event_list(
    event_list,
    normalize_red=True
)

# %%
import ROOT
import numpy as np
import matplotlib.pyplot as plt

def plot_digitTotalCharge_event_list(
    event_list,
    root_file="../Data/run7722all_metafix.root",
    tree_name="output",
    charge_leaf="digitCharge",
    bins=None,
    normalize_red=True
):
    import matplotlib.pyplot as plt
    from cycler import cycler

    eos_colors = [
        "violet",
        "royalblue",
        "springgreen",
        "forestgreen",
        "darkkhaki",
        "gold",
        "orangered",
        "brown",
    ]

    plt.rcParams["axes.ymargin"] = 0.05
    plt.rcParams["axes.xmargin"] = 0.05
    plt.rcParams["axes.prop_cycle"] = cycler(color=eos_colors)
    plt.rcParams["legend.fontsize"] = "x-large"
    plt.rcParams["legend.framealpha"] = 0
    plt.rcParams["legend.title_fontsize"] = "x-large"
    rdf = ROOT.RDataFrame(tree_name, root_file)

    # Read charge array branch
    digitCharge = rdf.AsNumpy(columns=[charge_leaf])[charge_leaf]

 # Sum only charges above 0.5 in each event
    digitTotalCharge = np.array(
        [np.sum(np.asarray(charges)[np.asarray(charges) > 0.5]) for charges in digitCharge],
        dtype=float
    )

    n_events = len(digitTotalCharge)

    event_list = np.array(event_list, dtype=int)
    event_list = event_list[(event_list >= 0) & (event_list < n_events)]

    selected_events = event_list
    all_events = np.arange(n_events, dtype=int)
    other_events = np.setdiff1d(all_events, selected_events)

    selected_charge = digitTotalCharge[selected_events]
    other_charge = digitTotalCharge[other_events]


    selected_counts, charge_bins = np.histogram(
        selected_charge,
        bins=np.arange(0,13000,520)
    )

    other_counts, _ = np.histogram(
        other_charge,
        bins=charge_bins
    )

    # Normalize red histogram to same total as blue histogram
    if normalize_red and np.sum(other_counts) > 0:
        other_counts = other_counts * np.sum(selected_counts) / np.sum(other_counts)

    charge_bin_centers = 0.5 * (
        charge_bins[:-1] + charge_bins[1:]
    )

    fig, ax = plt.subplots(figsize=(10, 9))

    ax.set_title("Total Integrated charge (pC) pass-through events vs all other events")

    ax.bar(
        charge_bin_centers,
        other_counts,
        width=520,
        color="royalblue",
        alpha=0.5,
        label=f"Not Triple Hits ({len(other_events)} events)",
        zorder = 3
    )

    ax.errorbar(
        charge_bin_centers,
        selected_counts,
        yerr=np.sqrt(selected_counts),
        xerr=260,
        color="black",
        marker=".",
        linestyle="",
        capsize=2,
        label=f"Triple Hits ({len(selected_events)} events)",
        zorder = 2
    )

    # ------------------------------------------------------------
    # Gaussian fit to triple-hit histogram around 10,000 pC
    # ------------------------------------------------------------
    from scipy.optimize import curve_fit
    def gaussian(x, A, mu, sigma):
        return A * np.exp(-0.5 * ((x - mu) / sigma)**2)
    
    fit_mask = (
        (charge_bin_centers >= 7000) &
        (charge_bin_centers <= 12500) &
        (selected_counts > 0)
    )

    fit_params = None
    fit_cov = None

    if np.count_nonzero(fit_mask) >= 3:
        x_fit_data = charge_bin_centers[fit_mask]
        y_fit_data = selected_counts[fit_mask]
        yerr_fit_data = np.sqrt(y_fit_data)

        p0 = [
            np.max(y_fit_data),  # amplitude
            10000.0,             # mean near 10,000 pC
            1000.0               # initial sigma guess
        ]

        bounds = (
            [0.0, 8000.0, 100.0],       # lower bounds: A, mu, sigma
            [np.inf, 12000.0, 5000.0]   # upper bounds: A, mu, sigma
        )

        try:
            fit_params, fit_cov = curve_fit(
                gaussian,
                x_fit_data,
                y_fit_data,
                p0=p0,
                sigma=yerr_fit_data,
                absolute_sigma=True,
                bounds=bounds,
                maxfev=10000
            )

            A_fit, mu_fit, sigma_fit = fit_params

            x_fit_curve = np.linspace(8000, 12500, 500)
            y_fit_curve = gaussian(x_fit_curve, A_fit, mu_fit, sigma_fit)

            ax.plot(
                x_fit_curve,
                y_fit_curve,
                color="orangered",
                linewidth=2.5,
                label=(
                    "Gaussian fit: "
                    rf"$\mu={mu_fit:.0f}$ pC, "
                    rf"$\sigma={sigma_fit:.0f}$ pC"
                ),
                zorder = 1
                
            )

            print("Gaussian fit to triple-hit histogram:")
            print(f"  A     = {A_fit:.3f}")
            print(f"  mu    = {mu_fit:.3f} pC")
            print(f"  sigma = {sigma_fit:.3f} pC")

        except RuntimeError:
            print("Gaussian fit failed.")
    else:
        print("Not enough nonzero bins near 10,000 pC for Gaussian fit.")
    
    ax.set_xlabel("Total Integrated charge (pC)", fontsize=14)
    ax.set_ylabel("Normalized to Number of Triple Hits (Arb. Units)", fontsize=14)
    ax.set_yscale("log")

    ax.legend(framealpha=0)

    plt.show()

    return selected_events, other_events, digitTotalCharge, selected_counts, other_counts

selected_events, other_events, digitTotalCharge, selected_counts, other_counts = (
    plot_digitTotalCharge_event_list(event_list)
)
# Out:
# Gaussian fit to triple-hit histogram:
#   A     = 20.778
#   mu    = 10217.862 pC
#   sigma = 1425.693 pC

# %%
total_counts = success_counts + fail_counts

# Avoid divide-by-zero where both are zero
fail_fraction = np.divide(
    fail_counts,
    total_counts,
    out=np.zeros_like(fail_counts, dtype=float),
    where=total_counts > 0
)

bad_cols = col_bin_centers[fail_fraction > 0.75].astype(int)

print("Columns with fail fraction > 75%:")
print(bad_cols.tolist())

print("\nDetailed:")
for col, frac, fail, success in zip(
    col_bin_centers.astype(int),
    fail_fraction,
    fail_counts,
    success_counts
):
    if frac > 0.75:
        print(
            f"column {col}: "
            f"fail_fraction = {100*frac:.1f}%, "
            f"fail = {fail:.2f}, "
            f"success = {success:.2f}"
        )

# %%
success_mask = success_counts > 0
fail_mask = fail_counts > 0

union_mask = success_mask | fail_mask
overlap_mask = success_mask & fail_mask
success_only_mask = success_mask & ~fail_mask
fail_only_mask = fail_mask & ~success_mask

print(f"Success columns:      {np.count_nonzero(success_mask)}")
print(f"Fail columns:         {np.count_nonzero(fail_mask)}")
print(f"Union columns:        {np.count_nonzero(union_mask)}")
print(f"Overlap columns:      {np.count_nonzero(overlap_mask)}")
print(f"Success-only columns: {np.count_nonzero(success_only_mask)}")
print(f"Fail-only columns:    {np.count_nonzero(fail_only_mask)}")

# %%
print(muon_pos_hits[0:4,80])

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from MuonTrack import *

fig = plt.figure(figsize=(12, 11))
ax = fig.add_subplot(111, projection="3d")

n_paddles = muon_pos_hits.shape[1]

for col in range(n_paddles):
    layer_value = int(muon_pos_hits[0, col])

    x = muon_pos_hits[1, col]
    y = muon_pos_hits[2, col]
    z = muon_pos_hits[3, col]

    size = box_size_from_layer(layer_value)

    if size is None:
        print(f"Skipping col {col}: unknown layer {layer_value}")
        continue

    if layer_value <= 0:
        continue

    if layer_value in [5, 6]:
        # Barrel paddle:
        # 210 wide tangentially, 10 thick radially, 1300 long in z
        radial_axis, tangential_axis, z_axis = barrel_axes_from_position(x, y)

        draw_oriented_box(
            ax,
            center=(x, y, z),
            axes=(tangential_axis, radial_axis, z_axis),
            size=(210, 10, 1300),
            alpha=0.15,
            facecolor=color_from_layer(layer_value)
        )

    else:
        # Non-barrel paddles remain axis-aligned
        draw_paddle(
            ax,
            center=(x, y, z),
            size=size,
            alpha=0.15,
            facecolor=color_from_layer(layer_value)
        )

    ax.text(x, y, z, str(col), fontsize=7)

ax.set_xlabel("x_pos")
ax.set_ylabel("y_pos")
ax.set_zlabel("z_pos")
ax.set_title("All Muon Paddles")

ax.set_xlim(-1600, 1600)
ax.set_ylim(-1600, 1600)
ax.set_zlim(-2200, 2200)

ax.set_box_aspect((3200, 3200, 4400))

plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Skipping col 10: unknown layer 0
# Skipping col 11: unknown layer 0
# Skipping col 51: unknown layer 0
# Skipping col 78: unknown layer 0
# Skipping col 81: unknown layer 0
# Skipping col 106: unknown layer 0
# Skipping col 107: unknown layer 0
# Skipping col 132: unknown layer 0
# Skipping col 133: unknown layer 0
